# %% [markdown]
# # Testing if model is working:

# %%
import joblib

joblib.load(
    r"C:\Users\Hi\Desktop\Risk-Analysis\models\readmission_logistic_model.pkl"
)

print("Model loaded successfully!")
# Out:
# Model loaded successfully!
